# %%
import igraph as ig
# usiamo un grafo famoso https://python.igraph.org/en/stable/generation.html#famous-graphs
g = ig.Graph.Barabasi(50)
print()
layout = g.layout("kk")
ig.plot(g, layout=layout)
